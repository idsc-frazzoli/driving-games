# %% [markdown]
# ### Set if you work in pycharm or in native jupyter environment (recommended): used for plotting

# %%
IN_PYCHARM : bool = False

# %% [markdown]
# ### Preliminary imports and settings

# %%
# Imports
from math import isclose
from copy import deepcopy
from IPython.display import clear_output
import networkx as nx
import numpy as np
from matplotlib import pyplot as plt

import contracts
import geometry as geo

import duckietown_world as dw
from duckietown_world.svg_drawing.ipython_utils import ipython_draw_html, ipython_draw_svg
from duckietown_world.world_duckietown.tile import get_lane_poses
from duckietown_world.world_duckietown.tile_utils import get_tile_at_point
from duckietown_world.rules.rule import evaluate_rules

from duckie_games.map_loading import load_driving_game_map

# Some settings
contracts.disable_all()
dw.logger.setLevel(50)
d = "out/"

class Person(dw.PlacedObject):

    def __init__(self, radius, *args, **kwargs):
        self.radius = radius
        dw.PlacedObject.__init__(self, *args, **kwargs)
        
    def draw_svg(self, drawing, g):
        # drawing is done using the library svgwrite
        c = drawing.circle(center=(0, 0), r=self.radius, fill='red')
        g.add(c)
        # draws x,y axes
        dw.draw_axes(drawing, g)

    def extent_points(self):
        # set of points describing the boundary 
        L = self.radius
        return [(-L, -L), (+L, +L)]
# Out:
# INFO:geometry:version: 2.0.5
# INFO:commons:version: 6.1.5
# INFO:typing:version: 6.1.8
# DEBUG:duckietown_world:duckietown-world version 6.2.7 path /home/chrigi/Master-Thesis-Code/driving-games/venv/lib/python3.8/site-packages

# %% [markdown]
# ### Define some useful functions

# %%
def draw_object(pl_ob: dw.PlacedObject, outdir=None, area=None, in_pycharm: bool = IN_PYCHARM):
    if in_pycharm:
        ipython_draw_html(po=pl_ob, outdir=outdir, area=area)
        clear_output(wait=True)
        ipython_draw_svg(m=pl_ob, outdir=outdir)
    else:
        ipython_draw_html(po=pl_ob, outdir=outdir, area=area)

def draw_graph(G0, pos=None):
    pos = pos or nx.spring_layout(G0)
    plt.figure(figsize=(12, 12))
    nx.draw(G0,pos,labels={node:node for node in G0.nodes()})
    def edge_label(a, b):
        datas = G0.get_edge_data(a, b)
        s = '%d edge%s' % (len(datas), 's' if len(datas)>=2 else '')
        for k, v in datas.items():
            if v:
                if 'label' in v:
                    s += '\n %s' % v['label']
                else:
                    s += '\n %s' %v
        return s
    edge_labels = dict([ ((a,b), edge_label(a,b)) for a,b in G0.edges()])
    nx.draw_networkx_edge_labels(G0,pos,edge_labels=edge_labels,font_color='red')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Better Visualisation of output

# %%
# %%html
# <style>
# pre {line-height: 90%}
# </style>
# Out:
# <style>
# pre {line-height: 90%}
# </style>

# %% [markdown]
# ### Import and draw the map

# %%
map_name = "4way-double"
dirname = d + map_name
duckie_map = load_driving_game_map(map_name)
draw_object(duckie_map, outdir=dirname)
# Out:
# INFO:duckietown_world: data: /home/chrigi/Master-Thesis-Code/driving-games/venv/lib/python3.8/site-packages/duckietown_world/data
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[34.46800009 34.46800009])
# DEBUG:commons.fs:already up to date out/4way-double/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/4way-double/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/4way-double/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Get skeleton graph (contains the lane segments and the graph interconnecting them)

# %%
skeleton_graph = dw.get_skeleton_graph(duckie_map)

# %% [markdown]
# ### Get the map of the joined lane segments and draw it (check box "map lane segments" to see it)

# %%
joined_lane_segments = skeleton_graph.root2

dirname = d + "4wayjoinedlane"
draw_object(joined_lane_segments, outdir=dirname)
# Out:
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[34.46800137 34.46800137])
# DEBUG:commons.fs:already up to date out/4wayjoinedlane/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/4wayjoinedlane/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/4wayjoinedlane/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Get the graph of the topology

# %%
topology_graph = skeleton_graph.G

# %% [markdown]
# ### Draw the graph

# %%
pos = {}
for n in topology_graph:
    q = topology_graph.nodes[n]['point'].as_SE2()
    t, _ = geo.translation_angle_from_SE2(q)
    pos[n] = t
draw_graph(topology_graph, pos=pos)

# %% [markdown]
# ### Extract the shortest path from a start node to an end node as list

# %%
start = "P42"
end = "P23"

path = nx.shortest_path(topology_graph, start, end)

def get_lanes(path, graph):
    edges = zip(path[:-1], path[1:])
    lanes =[]
    for a, b in edges:
        lane = graph.get_edge_data(a, b)[0]['lane']
        lanes.append(lane)
    return lanes

lanes = get_lanes(path, topology_graph)
print(lanes)
# Out:
# ['ls074', 'ls084', 'ls048', 'ls018', 'ls027']

# %% [markdown]
# ### Extract the lane segments and draw them

# %%
lane_segments_to_follow = [joined_lane_segments.children[lane_name] for lane_name in lanes]

lane_points = []
po = dw.PlacedObject()
for lane_name, lane in zip(lanes, lane_segments_to_follow):
    po.set_object(lane_name, lane, ground_truth=dw.SE2Transform.identity())

dirname = d + "extractedlane"
draw_object(po, outdir = dirname)
# Out:
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[28.         31.38799954])
# DEBUG:commons.fs:already up to date out/extractedlane/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/extractedlane/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/extractedlane/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Get the width of one of the lane segments

# %%
width = lane_segments_to_follow[0].width

# %% [markdown]
# ### Merge the extracted lane segments to have one unified lane

# %%
import itertools as it

# Make a list of all the control points, while making sure that the points that overlap are only taken once
lane_segments_to_follow_control_points = list(  
    it.chain(
        *[ls.control_points[:-1] if ls is not lane_segments_to_follow[-1]
          else ls.control_points for ls in lane_segments_to_follow]
    )
)

# Creating a unified lane segment
lane_segments_to_follow_unified = dw.LaneSegment(
    width=width, control_points=lane_segments_to_follow_control_points
)

# Draw the unified lane segment
po = dw.PlacedObject()
po.set_object("Unified Lane", lane_segments_to_follow_unified, ground_truth=dw.SE2Transform.identity())
dirname = d + "unified_lane"
draw_object(po, outdir=dirname)
# Out:
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[28.         31.38799954])
# DEBUG:commons.fs:Written 0.1MB to: out/unified_lane/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/unified_lane/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/unified_lane/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Check if the merged lane has the same total length as the sum of its parts

# %%
sum_lane_lengths = sum([ln.get_lane_length() for ln in lane_segments_to_follow])
sum_lane_segmenst_unified = lane_segments_to_follow_unified.get_lane_length()
msg = f"Lanes have not the same lenght: {sum_lane_lengths} is not {sum_lane_segmenst_unified}"
assert isclose(sum_lane_segmenst_unified , sum_lane_lengths, abs_tol=1e-5), msg

# %% [markdown]
# ### Get a person to follow the lane

# %%
big_duckie = Person(width / 2)

# %% [markdown]
# ### Interpolate along the center line

# %%
npoints = len(lane_segments_to_follow_unified.control_points) # get the control points of the lane
points = 15
betas = list(np.linspace(0, npoints-1, points))  # first control point beta=0, last control point beta=nbpoints-1

transforms = []
for beta in betas:
    p = lane_segments_to_follow_unified.center_point(beta)  # get interpolated pose in SE(2)
    transform = dw.SE2Transform.from_SE2(p)  # Transform to SE2Transform 
    transforms.append(transform)

ground_truth = dw.SampledSequence[dw.SE2Transform](betas, transforms) # Setting the sequence for animation
duckie_map_lanefollow = deepcopy(duckie_map)  # copy the map  to prevent adding objects to the "original" map
duckie_map_lanefollow.set_object("Duckie", big_duckie, ground_truth=ground_truth) # add a duckie with the sequence
dirname = d + "lane_follow_unified"
draw_object(duckie_map_lanefollow, outdir=dirname)
# Out:
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[34.46800009 34.46800009])
# DEBUG:commons.fs:Written 1.1MB to: out/lane_follow_unified/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/lane_follow_unified/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/lane_follow_unified/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Define functions to interpolate along center line beta=0 start beta=1 end

# %%
from typing import List

def interpolate(lane: dw.LaneSegment, beta: float) -> dw.SE2Transform:
    """ Interpolate along the centerline of a lane. Start: beta=0, End beta=1 """
    n_ctr_points = len(lane.control_points) # get the control points of the lane
    dw_beta = beta * (n_ctr_points - 1) # transform the beta to the beta used by duckietown world
    p = lane.center_point(dw_beta) # get the pose
    transform = dw.SE2Transform.from_SE2(p) # transform the pose
    return transform

def interpolate_n_points(lane: dw.LaneSegment, betas: List[float]) -> List[dw.SE2Transform]:
    """ Get pose sequence as a SE2Transform along the center line of a lane, beta=0 start beta=1 end """
    msg = f"betas = {betas} have to be in ascending order to follow a lane"
    assert all(map(isclose, sorted(betas), betas)), msg  # check if values are ascending
    transforms = [interpolate(lane, beta) for beta in betas]
    return transforms

# %% [markdown]
# ### Test the functions

# %%
points = 60 # number of interpolation points
betas = list(np.linspace(0,1,points))
timestamps = range(points)
transforms = interpolate_n_points(lane_segments_to_follow_unified, betas)  # get the pose sequence

# Animation
ground_truth = dw.SampledSequence[dw.SE2Transform](timestamps, transforms)
duckie_map_lanefollow = deepcopy(duckie_map)
duckie_map_lanefollow.set_object("Duckie", big_duckie, ground_truth=ground_truth)
dirname = d + "lane_follow_interpolated"
draw_object(duckie_map_lanefollow, outdir=dirname)
# Out:
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[34.46800009 34.46800009])
# DEBUG:commons.fs:Written 1.3MB to: out/lane_follow_interpolated/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/lane_follow_interpolated/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/lane_follow_interpolated/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Define functions to interpolate along the centerlines when the position along the lane is known

# %%
def interpolate_along_lane(lane: dw.LaneSegment, along_lane: float) -> dw.SE2Transform:
    """ Input: lane and 1D position along the lane. Output: Pose on the duckietown map """
    dw_beta = lane.beta_from_along_lane(along_lane=along_lane)  # get the beta in in the dw representation
    p = lane.center_point(dw_beta)  # get pose
    transform = dw.SE2Transform.from_SE2(p)
    return transform

def interpolate_along_lane_n_points(
    lane: dw.LaneSegment,
    positions_along_lane: List[float]
) -> List[dw.SE2Transform]:
    """ Input: lane and sequence of 1D positions along the lane. Output: Pose sequence on the duckietown map """
    msg = f"Positions={positions_along_lane} have to be in ascending order to follow a lane"
    assert all(map(isclose, sorted(positions_along_lane), positions_along_lane)), msg
    transforms = [interpolate_along_lane(lane, along_lane) for along_lane in positions_along_lane]
    return transforms

# %% [markdown]
# ### Test functions

# %%
max_length = lane_segments_to_follow_unified.get_lane_length()  # get total length of the lane
points = 100  # number of points to interpolate
positions_along_lane = list(np.linspace(0, max_length, points))  # sequence of 1D position along the lane
timestamps = range(points) # just number of points
transforms = interpolate_along_lane_n_points(lane_segments_to_follow_unified, positions_along_lane)

# Animation
ground_truth = dw.SampledSequence[dw.SE2Transform](timestamps, transforms)
duckie_map_lanefollow = deepcopy(duckie_map)
duckie_map_lanefollow.set_object("Duckie", big_duckie, ground_truth=ground_truth)
dirname = d + "lane_follow_along_lane_interpolated"
draw_object(duckie_map_lanefollow, outdir=dirname)
# Out:
# INFO:duckietown_world: area: RectangularArea(pmin=[0. 0.],pmax=[34.46800009 34.46800009])
# DEBUG:commons.fs:Written 1.4MB to: out/lane_follow_along_lane_interpolated/drawing.html
# INFO:duckietown_world:Written SVG
#  fn_svg: out/lane_follow_along_lane_interpolated/drawing.svg
#         <iframe
#             width="100%"
#             height="600"
#             src="out/lane_follow_along_lane_interpolated/drawing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Collection of other useful functions
#
# ### Sample some center line points of a lane (default 5 points)

# %%
lane_points = lane_segments_to_follow_unified.center_line_points()  # in SE(2)
print(lane_points)
# Out:
# [array([[ 1.00000000e+00,  2.44929371e-16,  7.00000000e+00],
#        [-2.44929371e-16,  1.00000000e+00,  1.51899996e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  8.42857143e+00],
#        [-2.44929371e-16,  1.00000000e+00,  1.51899996e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  9.85714286e+00],
#        [-2.44929371e-16,  1.00000000e+00,  1.51899996e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  1.12857143e+01],
#        [-2.44929371e-16,  1.00000000e+00,  1.51899996e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  1.27142857e+01],
#        [-2.44929371e-16,  1.00000000e+00,  1.51899996e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 0.99987155, -0.01602785, 14.09312999],
#        [ 0.01602785,  0.99987155, 15.19072658],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.98449693, -0.1754018 , 15.01919113],
#        [ 0.1754018 ,  0.98449693, 15.279868  ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.94388333, -0.33027907, 15.91915485],
#        [ 0.33027907,  0.94388333, 15.51566606],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.87907192, -0.47668917, 16.76994929],
#        [ 0.47668917,  0.87907192, 15.89207573],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.79172424, -0.61087865, 17.54976313],
#        [ 0.61087865,  0.79172424, 16.3994472 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.68407958, -0.72940736, 18.23854895],
#        [ 0.72940736,  0.68407958, 17.02482723],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.55889756, -0.82923669, 18.81845576],
#        [ 0.82923669,  0.55889756, 17.75231827],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.4193874 , -0.90780735, 19.2748217 ],
#        [ 0.90780735,  0.4193874 , 18.56303724],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.26912564, -0.96310506, 19.59594718],
#        [ 0.96310506,  0.26912564, 19.4362002 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.11196446, -0.99371219, 19.77359968],
#        [ 0.99371219,  0.11196446, 20.34942236],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.98099995e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.11071429e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.98099995e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.14642857e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.98099995e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.18214286e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.98099995e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.21785714e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.98099995e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.25357143e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[-0.06407022, -0.99794539, 19.80137828],
#        [ 0.99794539, -0.06407022, 22.90989937],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.22252094, -0.97492791, 19.73526271],
#        [ 0.97492791, -0.22252094, 23.30436614],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.37526701, -0.92691675, 19.60703777],
#        [ 0.92691675, -0.37526701, 23.6832245 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.51839258, -0.85514276, 19.41999068],
#        [ 0.85514276, -0.51839258, 24.0367619 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.64822841, -0.76144595, 19.17891668],
#        [ 0.76144595, -0.64822841, 24.35591487],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.64822838, -0.76144595, 18.90108501],
#        [ 0.76144595, -0.64822838, 24.64408485],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.51839255, -0.85514275, 18.66001063],
#        [ 0.85514275, -0.51839255, 24.9632373 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.37526699, -0.92691675, 18.4729631 ],
#        [ 0.92691675, -0.37526699, 25.31677424],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.22252091, -0.9749279 , 18.34473765],
#        [ 0.9749279 , -0.22252091, 25.69563223],
#        [ 0.        ,  0.        ,  1.        ]]), array([[-0.0640702 , -0.99794538, 18.27862151],
#        [ 0.99794538, -0.0640702 , 26.0900987 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.82700005e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.64642857e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.82700005e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.68214286e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.82700005e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.71785714e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.82700005e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.75357143e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 6.12323426e-17, -1.00000000e+00,  1.82700005e+01],
#        [ 1.00000000e+00,  6.12323426e-17,  2.78928571e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 0.11196448, -0.99371221, 18.28686779],
#        [ 0.99371221,  0.11196448, 28.30580664],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.26912566, -0.96310507, 18.37003111],
#        [ 0.96310507,  0.26912566, 28.73511767],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.41938742, -0.90780735, 18.52064642],
#        [ 0.90780735,  0.41938742, 29.14565284],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.55889759, -0.82923669, 18.73485248],
#        [ 0.82923669,  0.55889759, 29.5268875 ],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.68407961, -0.72940735, 19.00715782],
#        [ 0.72940735,  0.68407961, 29.86904814],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.79172424, -0.61087862, 19.33104314],
#        [ 0.61087862,  0.79172424, 30.16283791],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.87907191, -0.47668914, 19.69777026],
#        [ 0.47668914,  0.87907191, 30.40102957],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.94388332, -0.33027904, 20.09781195],
#        [ 0.33027904,  0.94388332, 30.57763843],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 0.98449692, -0.17540177, 20.52091258],
#        [ 0.17540177,  0.98449692, 30.68813687],
#        [ 0.        ,  0.        ,  1.        ]]), array([[ 9.99871529e-01, -1.60278259e-02,  2.09562253e+01],
#        [ 1.60278259e-02,  9.99871529e-01,  3.07296921e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  2.22857143e+01],
#        [-2.44929371e-16,  1.00000000e+00,  3.07299995e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  2.37142857e+01],
#        [-2.44929371e-16,  1.00000000e+00,  3.07299995e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  2.51428571e+01],
#        [-2.44929371e-16,  1.00000000e+00,  3.07299995e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  2.65714286e+01],
#        [-2.44929371e-16,  1.00000000e+00,  3.07299995e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]), array([[ 1.00000000e+00,  2.44929371e-16,  2.80000000e+01],
#        [-2.44929371e-16,  1.00000000e+00,  3.07299995e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]])]

# %% [markdown]
# ### Get the coordinates of the tile for a certain pose on the map

# %%
q = lane_points[2]  # some pose
tile_at_point = get_tile_at_point(duckie_map, q)
print(tile_at_point)
# Out:
# TileCoords(i=1,j=2,orientation=W)

# %% [markdown]
# ### Get a collection of useful information for the pose in the map

# %%
lane_poses = list(get_lane_poses(duckie_map, q))
print(lane_poses)
# Out:
# [GetLanePoseResult(tile=Tile(children={'straight_double': PlacedObject(children={'lane1': LaneSegment(children={}, spatial_relations={}), 'lane2': LaneSegment(children={}, spatial_relations={}), 'lane3': LaneSegment(children={}, spatial_relations={}), 'lane4': LaneSegment(children={}, spatial_relations={}), 'lane5': LaneSegment(children={}, spatial_relations={}), 'lane6': LaneSegment(children={}, spatial_relations={}), 'lane7': LaneSegment(children={}, spatial_relations={}), 'lane8': LaneSegment(children={}, spatial_relations={})}, spatial_relations={'lane1': GroundTruth(() -> ('lane1',)  SE2Transform([0.0, 0.0],0.0)), 'lane2': GroundTruth(() -> ('lane2',)  SE2Transform([0.0, 0.0],0.0)), 'lane3': GroundTruth(() -> ('lane3',)  SE2Transform([0.0, 0.0],180.0)), 'lane4': GroundTruth(() -> ('lane4',)  SE2Transform([0.0, 0.0],180.0)), 'lane5': GroundTruth(() -> ('lane5',)  SE2Transform([0.0, 0.0],0.0)), 'lane6': GroundTruth(() -> ('lane6',)  SE2Transform([0.0, 0.0],0.0)), 'lane7': GroundTruth(() -> ('lane7',)  SE2Transform([0.0, 0.0],180.0)), 'lane8': GroundTruth(() -> ('lane8',)  SE2Transform([0.0, 0.0],180.0))})}, spatial_relations={1: GroundTruth(() -> ('straight_double',)  SE2Transform([0.0, 0.0],0.0))}), tile_fqn=('tilemap', 'tile-1-2'), tile_transform=TransformSequence([Scale2D(scale=7), TileCoords(i=1,j=2,orientation=W)]), tile_relative_pose=Matrix2D(m=[[-1.4285715e-01 -1.7494956e-17  9.1836669e-02]
#  [ 1.7494956e-17 -1.4285715e-01  3.2999995e-01]
#  [ 0.0000000e+00  0.0000000e+00  1.0000000e+00]]), lane_segment=LaneSegment(children={}, spatial_relations={}), lane_segment_fqn=('tilemap', 'tile-1-2', 'straight_double', 'lane3'), lane_pose=LanePose(inside=True,lateral_inside=True,outside_left=False,outside_right=False,lateral=3.7061313518105266e-08,lateral_left=0.094,lateral_right=-0.094,along_inside=True,along_before=False,along_after=False,along_lane=0.40816332825592566,relative_heading=1.1428468025620557e-24,distance_from_left=0.09399996293868648,distance_from_right=0.09400003706131352,distance_from_center=3.7061313518105266e-08,center_point=SE2Transform([-0.09183667174407434, -0.33000001311302185],0.0),correct_direction=True), lane_segment_relative_pose=Matrix2D(m=[[ 1.4285715e-01 -1.6326384e-25 -9.1836669e-02]
#  [ 1.6326384e-25  1.4285715e-01 -3.2999995e-01]
#  [ 0.0000000e+00  0.0000000e+00  1.0000000e+00]]), tile_coords=TileCoords(i=1,j=2,orientation=W), lane_segment_transform=TransformSequence([Scale2D(scale=7), TileCoords(i=1,j=2,orientation=W), SE2Transform([0.0, 0.0],0.0), SE2Transform([0.0, 0.0],180.0)]), center_point=Matrix2D(m=[[ 7.0000000e+00  1.7145056e-15  9.8571434e+00]
#  [-1.7145056e-15  7.0000000e+00  1.5190000e+01]
#  [ 0.0000000e+00  0.0000000e+00  1.0000000e+00]])), GetLanePoseResult(tile=Tile(children={'straight_double': PlacedObject(children={'lane1': LaneSegment(children={}, spatial_relations={}), 'lane2': LaneSegment(children={}, spatial_relations={}), 'lane3': LaneSegment(children={}, spatial_relations={}), 'lane4': LaneSegment(children={}, spatial_relations={}), 'lane5': LaneSegment(children={}, spatial_relations={}), 'lane6': LaneSegment(children={}, spatial_relations={}), 'lane7': LaneSegment(children={}, spatial_relations={}), 'lane8': LaneSegment(children={}, spatial_relations={})}, spatial_relations={'lane1': GroundTruth(() -> ('lane1',)  SE2Transform([0.0, 0.0],0.0)), 'lane2': GroundTruth(() -> ('lane2',)  SE2Transform([0.0, 0.0],0.0)), 'lane3': GroundTruth(() -> ('lane3',)  SE2Transform([0.0, 0.0],180.0)), 'lane4': GroundTruth(() -> ('lane4',)  SE2Transform([0.0, 0.0],180.0)), 'lane5': GroundTruth(() -> ('lane5',)  SE2Transform([0.0, 0.0],0.0)), 'lane6': GroundTruth(() -> ('lane6',)  SE2Transform([0.0, 0.0],0.0)), 'lane7': GroundTruth(() -> ('lane7',)  SE2Transform([0.0, 0.0],180.0)), 'lane8': GroundTruth(() -> ('lane8',)  SE2Transform([0.0, 0.0],180.0))})}, spatial_relations={1: GroundTruth(() -> ('straight_double',)  SE2Transform([0.0, 0.0],0.0))}), tile_fqn=('tilemap', 'tile-1-2'), tile_transform=TransformSequence([Scale2D(scale=7), TileCoords(i=1,j=2,orientation=W)]), tile_relative_pose=Matrix2D(m=[[-1.4285715e-01 -1.7494956e-17  9.1836669e-02]
#  [ 1.7494956e-17 -1.4285715e-01  3.2999995e-01]
#  [ 0.0000000e+00  0.0000000e+00  1.0000000e+00]]), lane_segment=LaneSegment(children={}, spatial_relations={}), lane_segment_fqn=('tilemap', 'tile-1-2', 'straight_double', 'lane7'), lane_pose=LanePose(inside=True,lateral_inside=True,outside_left=False,outside_right=False,lateral=-0.036627415622760506,lateral_left=0.094,lateral_right=-0.094,along_inside=True,along_before=False,along_after=False,along_lane=0.39830506852877867,relative_heading=-0.41558154037894723,distance_from_left=0.1306274156227605,distance_from_right=0.057372584377239494,distance_from_center=0.036627415622760506,center_point=SE2Transform([-0.10662375603641946, -0.29649011791686447],23.8),correct_direction=True), lane_segment_relative_pose=Matrix2D(m=[[ 1.4285715e-01 -1.6326384e-25 -9.1836669e-02]
#  [ 1.6326384e-25  1.4285715e-01 -3.2999995e-01]
#  [ 0.0000000e+00  0.0000000e+00  1.0000000e+00]]), tile_coords=TileCoords(i=1,j=2,orientation=W), lane_segment_transform=TransformSequence([Scale2D(scale=7), TileCoords(i=1,j=2,orientation=W), SE2Transform([0.0, 0.0],0.0), SE2Transform([0.0, 0.0],180.0)]), center_point=Matrix2D(m=[[ 6.404172  -2.8260543  9.7536335]
#  [ 2.8260543  6.404172  15.424569 ]
#  [ 0.         0.         1.       ]]))]

# %% [markdown]
# ### Get the evaluation of a simulated sequence

# %%
timestamps_as_floats = list(map(float, timestamps))  # timestamps have to be floats for it to work
evaluated_rules = evaluate_rules(
    poses_sequence=ground_truth,
    interval=dw.SampledSequence[dw.Timestamp](timestamps_as_floats, timestamps_as_floats),
    world=duckie_map,
    ego_name="Duckie"
)
for key, item in evaluated_rules.items():
    print(f"{key} : {item}\n")
# Out:
# deviation-heading : RuleEvaluationResult(<duckietown_world.rules.in_drivable_lane.DeviationHeading object at 0x7ff9def02bb0>, {(): EvaluatedMetric(Deviation from lane direction, 1.9863819702390274e-05)})
#
# in-drivable-lane : RuleEvaluationResult(<duckietown_world.rules.in_drivable_lane.InDrivableLane object at 0x7ff9def02820>, {(): EvaluatedMetric(Drivable areas, 0.0)})
#
# deviation-center-line : RuleEvaluationResult(<duckietown_world.rules.in_drivable_lane.DeviationFromCenterLine object at 0x7ff9def024f0>, {(): EvaluatedMetric(Deviation from center line, 9.821783060789957e-06)})
#
# driving-distance : RuleEvaluationResult(<duckietown_world.rules.in_drivable_lane.DrivenLength object at 0x7ff9def02c70>, {('driven_any',): EvaluatedMetric(Distance, 34.8336725374828), ('driven_lanedir',): EvaluatedMetric(Lane distance, 34.811107671254746)})
#
# driving-distance-consecutive : RuleEvaluationResult(<duckietown_world.rules.in_drivable_lane.DrivenLengthConsecutive object at 0x7ff9def029d0>, {('driven_lanedir_consec',): EvaluatedMetric(Consecutive lane distance, 30.77845293234825)})
#
# survival_time : RuleEvaluationResult(<duckietown_world.rules.in_drivable_lane.SurvivalTime object at 0x7ff9def31550>, {(): EvaluatedMetric(Survival time, 99.0)})

# %% [markdown]
# ### Get a LanePose for a certain pose with very detailed information
#
# Information about the "position in the lane"
# Am I inside the lane? If not why not?

# %%
lane_pose = lane_segments_to_follow_unified.lane_pose_from_SE2(q)
print(lane_pose)
print("\n")
print(lane_pose.inside)
print("\n")
print(lane_pose.correct_direction)
# Out:
# LanePose(inside=True,lateral_inside=True,outside_left=False,outside_right=False,lateral=0.0,lateral_left=0.658,lateral_right=-0.658,along_inside=True,along_before=False,along_after=False,along_lane=2.8570476313968887,relative_heading=0.0,distance_from_left=0.658,distance_from_right=0.658,distance_from_center=0.0,center_point=SE2Transform([9.857047631396888, 15.189999580383299],-0.0),correct_direction=True)
#
#
# True
#
#
# True
